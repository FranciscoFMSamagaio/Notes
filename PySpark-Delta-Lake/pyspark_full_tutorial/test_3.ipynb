# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

java_home = Path("/usr/local/opt/openjdk@17")
if not java_home.exists():
    java_home = Path("/opt/homebrew/opt/openjdk@17")

os.environ["JAVA_HOME"] = str(java_home)
os.environ["PATH"] = f"{java_home / 'bin'}:{os.environ['PATH']}"
os.environ.setdefault("SPARK_LOCAL_IP", "127.0.0.1")

print(f"Python: {sys.executable}")
print(f"JAVA_HOME: {os.environ['JAVA_HOME']}")
# Out:
# Python: /Users/franciscosamagaio/Documents/Pyspark/.venv/bin/python
# JAVA_HOME: /usr/local/opt/openjdk@17

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# /Users/franciscosamagaio/Documents/Pyspark/.venv/lib/python3.13/site-packages/pyspark/sql/connect/utils.py:41: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# /Users/franciscosamagaio/Documents/Pyspark/.venv/lib/python3.13/site-packages/pyspark/testing/utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/08/31 12:32:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark

# %%
df_pyspark=spark.read.csv('test2.csv', header=True, inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.drop('Name').show()
# Out:
# +----+----------+------+
# | age|Experience|Salary|
# +----+----------+------+
# |  31|        10| 30000|
# |  30|         8| 25000|
# |  29|         4| 20000|
# |  24|         3| 20000|
# |  21|         1| 15000|
# |  23|         2| 18000|
# |NULL|      NULL| 40000|
# |  34|        10| 38000|
# |  36|      NULL|  NULL|
# +----+----------+------+

# %%
df_pyspark.na.drop().show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.na.drop(how='all').show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# |     NULL|  36|      NULL|  NULL|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how='any').show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.na.drop(how='any', thresh=2).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# |     NULL|  34|        10| 38000|
# +---------+----+----------+------+

# %%
df_pyspark.na.drop(how='all', subset=['Name']).show()
# Out:
# +---------+----+----------+------+
# |     Name| age|Experience|Salary|
# +---------+----+----------+------+
# |    Krish|  31|        10| 30000|
# |Sudhanshu|  30|         8| 25000|
# |    Sunny|  29|         4| 20000|
# |     Paul|  24|         3| 20000|
# |   Harsha|  21|         1| 15000|
# |  Shubham|  23|         2| 18000|
# |   Mahesh|NULL|      NULL| 40000|
# +---------+----+----------+------+

# %%
df_pyspark.na.fill('Missing Value').show()
# Out:
# +-------------+----+----------+------+
# |         Name| age|Experience|Salary|
# +-------------+----+----------+------+
# |        Krish|  31|        10| 30000|
# |    Sudhanshu|  30|         8| 25000|
# |        Sunny|  29|         4| 20000|
# |         Paul|  24|         3| 20000|
# |       Harsha|  21|         1| 15000|
# |      Shubham|  23|         2| 18000|
# |       Mahesh|NULL|      NULL| 40000|
# |Missing Value|  34|        10| 38000|
# |Missing Value|  36|      NULL|  NULL|
# +-------------+----+----------+------+

# %%
df_pyspark.na.fill('Missing Value', ['Name']).show()
# Out:
# +-------------+----+----------+------+
# |         Name| age|Experience|Salary|
# +-------------+----+----------+------+
# |        Krish|  31|        10| 30000|
# |    Sudhanshu|  30|         8| 25000|
# |        Sunny|  29|         4| 20000|
# |         Paul|  24|         3| 20000|
# |       Harsha|  21|         1| 15000|
# |      Shubham|  23|         2| 18000|
# |       Mahesh|NULL|      NULL| 40000|
# |Missing Value|  34|        10| 38000|
# |Missing Value|  36|      NULL|  NULL|
# +-------------+----+----------+------+

# %%
from pyspark.ml.feature import Imputer

imputer=Imputer(
    inputCols=['Age','Salary','Experience'], 
    outputCols=['{}_imputed'.format(c) for c in ['Age','Salary','Experience']]
    ).setStrategy('mean')

# %%
imputer.fit(df_pyspark).transform(df_pyspark).show()
# Out:
# /Users/franciscosamagaio/Documents/Pyspark/.venv/lib/python3.13/site-packages/pyspark/sql/connect/utils.py:41: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# +---------+----+----------+------+-----------+--------------+------------------+
# |     Name| age|Experience|Salary|Age_imputed|Salary_imputed|Experience_imputed|
# +---------+----+----------+------+-----------+--------------+------------------+
# |    Krish|  31|        10| 30000|         31|         30000|                10|
# |Sudhanshu|  30|         8| 25000|         30|         25000|                 8|
# |    Sunny|  29|         4| 20000|         29|         20000|                 4|
# |     Paul|  24|         3| 20000|         24|         20000|                 3|
# |   Harsha|  21|         1| 15000|         21|         15000|                 1|
# |  Shubham|  23|         2| 18000|         23|         18000|                 2|
# |   Mahesh|NULL|      NULL| 40000|         28|         40000|                 5|
# |     NULL|  34|        10| 38000|         34|         38000|                10|
# |     NULL|  36|      NULL|  NULL|         36|         25750|                 5|
# +---------+----+----------+------+-----------+--------------+------------------+

# %% [markdown]
# ## Filters

# %%
df_pyspark.filter(df_pyspark['Salary'] <= 20000).select(['Name', 'age', 'Salary']).show()
# Out:
# +-------+---+------+
# |   Name|age|Salary|
# +-------+---+------+
# |  Sunny| 29| 20000|
# |   Paul| 24| 20000|
# | Harsha| 21| 15000|
# |Shubham| 23| 18000|
# +-------+---+------+

# %%
df_pyspark.filter('Salary<=20000').select(['Name', 'age', 'Salary']).show()
# Out:
# +-------+---+------+
# |   Name|age|Salary|
# +-------+---+------+
# |  Sunny| 29| 20000|
# |   Paul| 24| 20000|
# | Harsha| 21| 15000|
# |Shubham| 23| 18000|
# +-------+---+------+
